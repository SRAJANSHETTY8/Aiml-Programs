# %%
list(range(20,24,25))
# Out:
# [20]

# %%
l=[1,2,3,4]
l[1]=3
print(l)
# Out:
# [1, 3, 3, 4]

# %%
l=['b','y','e']
l.append('r')
print(l)
# Out:
# ['b', 'y', 'e', 'r']

# %%
l=['b','y','e']
l=l+['m']
print(l)
# Out:
# ['b', 'y', 'e', 'm']

# %%
l=['b','y','e']
l.pop(1)
print(l)
# Out:
# ['b', 'e']

# %%
a=[2,4,8,1]
a.sort()
print(a)
# Out:
# [1, 2, 4, 8]

# %%
# Accept a list with numbers having 10 elements. Remove the third element and all odd elements.
numbers = []

print("Enter 10 numbers:")
for i in range(10):
    num = int(input(f"Enter number {i+1}: "))
    numbers.append(num)
if len(numbers) >= 3:
    del numbers[2]
numbers = [num for num in numbers if num % 2 == 0]
print("Final list after removing the third element and all odd numbers:")
print(numbers)
# Out:
# Enter 10 numbers:
