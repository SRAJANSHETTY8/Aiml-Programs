# %%
#dictionary
info={"car":"BMW","bikes":"Kawasaki"}
print(info["car"])
# Out:
# BMW

# %%
name_age={"ram":20,"hari":25}
print(name_age)
# Out:
# {'ram': 20, 'hari': 25}

# %%
word={}
word["hello"]="World"
word["HELLO"]="welcome"
print(word)
# Out:
# {'hello': 'World', 'HELLO': 'welcome'}

# %%
# Write a program to input ‘n’ employee numbers and names and store them in a dictionary. Display dictionaries employee’s names(key) and numbers(values) together
employee={}
while True:
    new_employee=input("eneter new employee")
    new_numbers=int(input("eneter new employee"))
    employee[new_employee]=new_numbers
    print(employee)
    break
# Out:
# eneter new employee emplyee1
# eneter new employee 556265
# {'emplyee1': 556265}
